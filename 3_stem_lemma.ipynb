# %% [markdown]
# # Stemming
# ## doesnt have a dictionary in it

# %% [markdown]
# stemming gives stem

# %%
from nltk.stem import PorterStemmer
words=['eat','eaten','broke','break','broken','bride','class','classify','nation','probation']
stemmer=PorterStemmer()
for word in words:
    print("word is --->", stemmer.stem(word))
# Out:
# word is ---> eat
# word is ---> eaten
# word is ---> broke
# word is ---> break
# word is ---> broken
# word is ---> bride
# word is ---> class
# word is ---> classifi
# word is ---> nation
# word is ---> probat

# %% [markdown]
# ## Notice how many words are wrongly stemmed

# %%
#regexstemming
from nltk.stem import RegexpStemmer
stemmer=RegexpStemmer('ing$|ed$', min=4)
for word in words:
    print("words are --->", stemmer.stem(word))
# Out:
# words are ---> eat
# words are ---> eaten
# words are ---> broke
# words are ---> break
# words are ---> broken
# words are ---> bride
# words are ---> class
# words are ---> classify
# words are ---> nation
# words are ---> probation

# %%
#snowballstemming
from nltk.stem import SnowballStemmer
snowball_stemmer=SnowballStemmer('english')
for word in words:
    print(snowball_stemmer.stem(word))
# Out:
# eat
# eaten
# broke
# break
# broken
# bride
# class
# classifi
# nation
# probat

# %% [markdown]
# # LEMMATIZATION

# %% [markdown]
# lemma is the root word

# %% [markdown]
# word net lemmatizer

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\snigdha\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
words=['eat','eaten','broke','break','broken','bride','class','classify','nation','probation']
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()
for word in words:
    print(word+ "--->",lemmatizer.lemmatize(word))
# Out:
# eat---> eat
# eaten---> eaten
# broke---> broke
# break---> break
# broken---> broken
# bride---> bride
# class---> class
# classify---> classify
# nation---> nation
# probation---> probation

# %% [markdown]
# # STOPWORDS

# %% [markdown]
# full sequence is
#
#
#
#
# Raw Text
#    ↓
# Tokenization +
# Lowercase Conversion
#    ↓
# Stopword Removal
#    ↓
# Stemming / Lemmatization
#    ↓
# Cleaned Text
#    ↓
# Vectorization (Bag of Words, TF-IDF, Word Embeddings)
#    ↓
# Machine Learning Model

# %%
# raw text

paragraph="""" 
Dr Abdul Kalam started his career as a scientist in the DRDO, 
and later promoted to work under the renowned space scientist Dr Vikram Sarabhai. 
He learnt the best leadership qualities from Prof. Sarabhai. 
Kalam's sincere work in designing a hovercraft and working efficiently was noticed by authorities. 
In 1969 he was transferred to the Indian Space Research Organization. 
Here Kalam was made the director of India's first Satellite Launch Vehicle system known as SLV-III. 
It was during this period he worked under Prof. Sathish Dhawan. 
Dr Kalam was given all the liberty and resources to develop the SLV-III. 
With a team of hundreds of workers including tens of scientists, 
Kalam worked day and night for this dream project. 

Little did he know that this project would be a failure when he tested it first. 
It was a huge failure for ISRO and Kalam personally. 
This is where the Missile Man understood how to handle failures more than success. 
He says that at the time of failure, you need to possess strong will and perseverance to overcome it. With full support from Prof. Sathish Dhawan, Kalam launched the project for the second time, despite criticism from the media and other scientific communities. 
This time it was successful and India marked a remarkable milestone in the history of Rocketry. 
In his autobiography, Kalam tells that though this success gave him joy, he still felt sad because he did not have his parents alive to see his achievement. 
"""

# %%
#WORD tokenization with lowercase conversion
from nltk.tokenize import word_tokenize
words=word_tokenize(paragraph.lower())
words
# Out:
# ['``',
#  'dr',
#  'abdul',
#  'kalam',
#  'started',
#  'his',
#  'career',
#  'as',
#  'a',
#  'scientist',
#  'in',
#  'the',
#  'drdo',
#  ',',
#  'and',
#  'later',
#  'promoted',
#  'to',
#  'work',
#  'under',
#  'the',
#  'renowned',
#  'space',
#  'scientist',
#  'dr',
#  'vikram',
#  'sarabhai',
#  '.',
#  'he',
#  'learnt',
#  'the',
#  'best',
#  'leadership',
#  'qualities',
#  'from',
#  'prof.',
#  'sarabhai',
#  '.',
#  'kalam',
#  "'s",
#  'sincere',
#  'work',
#  'in',
#  'designing',
#  'a',
#  'hovercraft',
#  'and',
#  'working',
#  'efficiently',
#  'was',
#  'noticed',
#  'by',
#  'authorities',
#  '.',
#  'in',
#  '1969',
#  'he',
#  'was',
#  'transferred',
#  'to',
#  'the',
#  'indian',
#  'space',
#  'research',
#  'organization',
#  '.',
#  'here',
#  'kalam',
#  'was',
#  'made',
#  'the',
#  'director',
#  'of',
#  'india',
#  "'s",
#  'first',
#  'satellite',
#  'launch',
#  'vehicle',
#  'system',
#  'known',
#  'as',
#  'slv-iii',
#  '.',
#  'it',
#  'was',
#  'during',
#  'this',
#  'period',
#  'he',
#  'worked',
#  'under',
#  'prof.',
#  'sathish',
#  'dhawan',
#  '.',
#  'dr',
#  'kalam',
#  'was',
#  'given',
#  'all',
#  'the',
#  'liberty',
#  'and',
#  'resources',
#  'to',
#  'develop',
#  'the',
#  'slv-iii',
#  '.',
#  'with',
#  'a',
#  'team',
#  'of',
#  'hundreds',
#  'of',
#  'workers',
#  'including',
#  'tens',
#  'of',
#  'scientists',
#  ',',
#  'kalam',
#  'worked',
#  'day',
#  'and',
#  'night',
#  'for',
#  'this',
#  'dream',
#  'project',
#  '.',
#  'little',
#  'did',
#  'he',
#  'know',
#  'that',
#  'this',
#  'project',
#  'would',
#  'be',
#  'a',
#  'failure',
#  'when',
#  'he',
#  'tested',
#  'it',
#  'first',
#  '.',
#  'it',
#  'was',
#  'a',
#  'huge',
#  'failure',
#  'for',
#  'isro',
#  'and',
#  'kalam',
#  'personally',
#  '.',
#  'this',
#  'is',
#  'where',
#  'the',
#  'missile',
#  'man',
#  'understood',
#  'how',
#  'to',
#  'handle',
#  'failures',
#  'more',
#  'than',
#  'success',
#  '.',
#  'he',
#  'says',
#  'that',
#  'at',
#  'the',
#  'time',
#  'of',
#  'failure',
#  ',',
#  'you',
#  'need',
#  'to',
#  'possess',
#  'strong',
#  'will',
#  'and',
#  'perseverance',
#  'to',
#  'overcome',
#  'it',
#  '.',
#  'with',
#  'full',
#  'support',
#  'from',
#  'prof.',
#  'sathish',
#  'dhawan',
#  ',',
#  'kalam',
#  'launched',
#  'the',
#  'project',
#  'for',
#  'the',
#  'second',
#  'time',
#  ',',
#  'despite',
#  'criticism',
#  'from',
#  'the',
#  'media',
#  'and',
#  'other',
#  'scientific',
#  'communities',
#  '.',
#  'this',
#  'time',
#  'it',
#  'was',
#  'successful',
#  'and',
#  'india',
#  'marked',
#  'a',
#  'remarkable',
#  'milestone',
#  'in',
#  'the',
#  'history',
#  'of',
#  'rocketry',
#  '.',
#  'in',
#  'his',
#  'autobiography',
#  ',',
#  'kalam',
#  'tells',
#  'that',
#  'though',
#  'this',
#  'success',
#  'gave',
#  'him',
#  'joy',
#  ',',
#  'he',
#  'still',
#  'felt',
#  'sad',
#  'because',
#  'he',
#  'did',
#  'not',
#  'have',
#  'his',
#  'parents',
#  'alive',
#  'to',
#  'see',
#  'his',
#  'achievement',
#  '.']

# %%
# filtering stopwords and stemming the filtered words
# before that let's make sure stopwords is present with us

stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  'shouldn',
#  "shouldn't",
#  "should've",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  'were',
#  'weren',
#  "weren't",
#  "we've",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  'your',
#  "you're",
#  'yours',
#  'yourself',
#  'yourselves',
#  "you've"]

# %%
#actually we might need the sentences tokens as well so might as well tokenize
#sentences from paragraph as well

from nltk.tokenize import sent_tokenize
sentences=sent_tokenize(paragraph)

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords

stemmer = PorterStemmer()

for i in range(len(sentences)):
    words = [stemmer.stem(word)
             for word in sentences[i]
             if word not in set(stopwords.words('english'))]

    sentences[i] = ' '.join(words)

for sentence in sentences:
    print(sentence)
# Out:
# "
#  d r   a b u l   k l   r e   h   c r e e r       c e n   n   h e   d r d o ,
#  n   l e r   p r e     w r k   u n e r   h e   r e n w n e   p c e   c e n   d r   v k r   s r b h .
# h e   l e r n   h e   b e   l e e r h p   q u l e   f r   p r f .   s r b h .
# k l '   n c e r e   w r k   n   e g n n g     h v e r c r f   n   w r k n g   e f f c e n l   w   n c e   b   u h r e .
# i n   1 9 6 9   h e   w   r n f e r r e     h e   i n n   s p c e   r e e r c h   o r g n z n .
# h e r e   k l   w   e   h e   r e c r   f   i n '   f r   s e l l e   l u n c h   v e h c l e   e   k n w n     s l v - i i i .
# i   w   u r n g   h   p e r   h e   w r k e   u n e r   p r f .   s h h   d h w n .
# d r   k l   w   g v e n   l l   h e   l b e r   n   r e u r c e     e v e l p   h e   s l v - i i i .
# w h     e   f   h u n r e   f   w r k e r   n c l u n g   e n   f   c e n ,
#  k l   w r k e     n   n g h   f r   h   r e   p r j e c .
# l l e     h e   k n w   h   h   p r j e c   w u l   b e     f l u r e   w h e n   h e   e e     f r .
# i   w     h u g e   f l u r e   f r   i s r o   n   k l   p e r n l l .
# t h     w h e r e   h e   m l e   m n   u n e r   h w     h n l e   f l u r e   r e   h n   u c c e .
# h e     h     h e   e   f   f l u r e ,   u   n e e     p e   r n g   w l l   n   p e r e v e r n c e     v e r c e   .
# w h   f u l l   u p p r   f r   p r f .   s h h   d h w n ,   k l   l u n c h e   h e   p r j e c   f r   h e   e c n   e ,   e p e   c r c   f r   h e   e   n   h e r   c e n f c   c u n e .
# t h   e     w   u c c e f u l   n   i n   r k e     r e r k b l e   l e n e   n   h e   h r   f   r c k e r .
# i n   h   u b g r p h ,   k l   e l l   h   h u g h   h   u c c e   g v e   h   j ,   h e   l l   f e l     b e c u e   h e     n   h v e   h   p r e n   l v e     e e   h   c h e v e e n .
